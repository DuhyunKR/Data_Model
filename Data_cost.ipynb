# %%
import pandas as pd

# %%
df_list = pd.read_csv("A회사_보습제_매출데이터_V1.csv", encoding="cp949")

# %%
df_list.head()
#매출데이터 월별 표시
# Out:
#   Unnamed: 0          Sep          Oct          Nov          Dec          Jan  \
# 0        총매출  $5,280,000   $5,501,000   $5,469,000   $5,480,000   $5,533,000
# 1       목표매출  $5,280,000   $5,500,000   $5,729,000   $5,968,000   $6,217,000
# 2       광고비용  $1,056,000     $950,400     $739,200     $528,000     $316,800
# 3   소셜네트워크비용          $0     $105,600     $316,800     $528,000     $739,200
# 4     1온스별단가       $2.00        $2.00        $2.00        $1.90        $1.90
#
#            Feb
# 0  $5,554,000
# 1  $6,476,000
# 2    $316,800
# 3    $739,200
# 4       $1.90

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
month = ['Set', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
# 막대그래프 너비값
bar_width = 0.4
#광고비용
adv_money = [105, 95, 74, 53, 31, 31]
#소셜네트워크비용
sns_money = [0,11, 32, 53, 74, 74]
index = np.arange(len(month))
#목표매출 막대 그래프
plt.bar(index, adv_money, color = 'r', align = 'edge', width = bar_width, 
        label = '광고비용')
#총매출
plt.bar(index+bar_width, sns_money, color = 'blue', align = 'edge', width = bar_width,
       label = '소셜네트워크비용')
plt.legend()
plt.xticks(index + bar_width, month)
plt.xlabel("월")
plt.ylabel('매출(십만원단위)')
plt.title('광고비용과 소셜네트워크비용 비교')
plt.show()
